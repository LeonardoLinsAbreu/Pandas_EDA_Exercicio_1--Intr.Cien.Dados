# %%
import pandas as pd
url = "https://drive.google.com/uc?export=download&id=1eJ-L0MnJxHi929fZrVOKxH7Mrw5eTGpk"
df = pd.read_csv(url)
# Out:
# /tmp/ipykernel_15011/2739466525.py:3: DtypeWarning: Columns (0,3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %% [markdown]
# # Atividade 1 — Exercícios com os comandos básicos de pandas para EDA
#
#
# Responda as perguntas abaixo no notebook (cada resposta deve ter ao menos uma célula de código que produza o output e, logo abaixo, uma célula de texto com a sua interpretação).

# %% [markdown]
# ## 1) Carregue o dataset e mostre as primeiras 10 linhas.

# %%
df.head(10)
# Out:
#   Código da Emenda  Ano da Emenda  \
# 0   Sem informação           2014
# 1   Sem informação           2014
# 2   Sem informação           2014
# 3   Sem informação           2014
# 4   Sem informação           2014
# 5   Sem informação           2014
# 6   Sem informação           2014
# 7   Sem informação           2014
# 8   Sem informação           2014
# 9   Sem informação           2014
#
#                                       Tipo de Emenda  \
# 0  Emenda Individual - Transferências com Finalid...
# 1  Emenda Individual - Transferências com Finalid...
# 2  Emenda Individual - Transferências com Finalid...
# 3  Emenda Individual - Transferências com Finalid...
# 4  Emenda Individual - Transferências com Finalid...
# 5  Emenda Individual - Transferências com Finalid...
# 6  Emenda Individual - Transferências com Finalid...
# 7  Emenda Individual - Transferências com Finalid...
# 8  Emenda Individual - Transferências com Finalid...
# ...

# %% [markdown]
# Podemos obsevar uma tabela contendo várias informações, de vários tipos.

# %% [markdown]
# ## 2) Quantas linhas e colunas o dataset possui?

# %%
df.shape
# Out:
# (88596, 28)

# %% [markdown]
# Basicamente a função "df.shape" mostra a quantidade de linhas e colunas, no qual o primeiro número "88596" representa a quantidade de linhas, e o segundo número "28" representa a quantidade de colunas.

# %% [markdown]
# ## 3) Liste os nomes das colunas e descreva brevemente o que você entende que cada coluna representa.

# %%
df.columns
# Out:
# Index(['Código da Emenda', 'Ano da Emenda', 'Tipo de Emenda',
#        'Código do Autor da Emenda', 'Nome do Autor da Emenda',
#        'Número da emenda', 'Localidade de aplicação do recurso',
#        'Código Município IBGE', 'Município', 'Código UF IBGE', 'UF', 'Região',
#        'Código Função', 'Nome Função', 'Código Subfunção', 'Nome Subfunção',
#        'Código Programa', 'Nome Programa', 'Código Ação', 'Nome Ação',
#        'Código Plano Orçamentário', 'Nome Plano Orçamentário',
#        'Valor Empenhado', 'Valor Liquidado', 'Valor Pago',
#        'Valor Restos A Pagar Inscritos', 'Valor Restos A Pagar Cancelados',
#        'Valor Restos A Pagar Pagos'],
#       dtype='object')

# %% [markdown]
# Basicamente, podemos observar que existem 28 colunas contendo informções únicas, sendo cada:
#
# • Código da Emenda: Identificador único da
# emenda parlamentar.
#
# • 	Ano da Emenda: Ano em que a emenda foi apresentada ou aprovada.
#
# • 	Tipo de Emenda: Classificação da emenda (individual, de bancada, de comissão etc.).
#
# • 	Código do Autor da Emenda: Identificador numérico do autor da emenda.
#
# • 	Nome do Autor da Emenda: Nome completo do parlamentar ou entidade que propôs a emenda.
#
# • 	Número da Emenda: Número sequencial atribuído à emenda.
#
# • 	Localidade de aplicação do recurso: Local onde os recursos da emenda serão aplicados.
#
# • 	Código Município IBGE: Código oficial do município segundo o IBGE.
#
# • 	Município: Nome do município beneficiado.
#
# • 	Código UF IBGE: Código da Unidade Federativa segundo o IBGE.
#
# • 	UF: Sigla da Unidade Federativa (estado).
#
# • 	Região: Região geográfica do Brasil (Norte, Nordeste, Centro-Oeste, Sudeste, Sul).
#
# • 	Código Função: Código da função orçamentária (ex.: Saúde, Educação).
#
# • 	Nome Função: Nome da função orçamentária correspondente.
#
# • 	Código Subfunção: Código da subfunção dentro da função orçamentária.
#
# • 	Nome Subfunção: Nome da subfunção correspondente.
#
# • 	Código Programa: Código do programa de governo vinculado à emenda.
#
# • 	Nome Programa: Nome do programa de governo.
#
# • 	Código Ação: Código da ação orçamentária específica.
#
# • 	Nome Ação: Nome da ação orçamentária correspondente.
#
# • 	Código Plano Orçamentário: Código do plano orçamentário vinculado.
#
# • 	Nome Plano Orçamentário: Nome do plano orçamentário correspondente.
#
# • 	Valor Empenhado: Valor autorizado e reservado para execução da despesa.
#
# • 	Valor Liquidado: Valor da despesa efetivamente realizada e reconhecida.
#
# • 	Valor Pago: Valor efetivamente pago ao fornecedor ou beneficiário.
#
# • 	Valor Restos A Pagar Inscritos: Valores de despesas empenhadas, mas não pagas até o fim do exercício.
#
# • 	Valor Restos A Pagar Cancelados: Valores de restos a pagar que foram
# anulados.
#
# • 	Valor Restos A Pagar Pagos: Valores de restos a pagar que foram efetivamente quitados.

# %% [markdown]
# ## 4) Existem valores nulos? quantos?

# %%
df.isnull().sum()
# Out:
# Código da Emenda                      0
# Ano da Emenda                         0
# Tipo de Emenda                        0
# Código do Autor da Emenda             0
# Nome do Autor da Emenda               0
# Número da emenda                      0
# Localidade de aplicação do recurso    0
# Código Município IBGE                 0
# Município                             0
# Código UF IBGE                        0
# UF                                    0
# Região                                0
# Código Função                         0
# Nome Função                           0
# Código Subfunção                      0
# Nome Subfunção                        0
# Código Programa                       0
# Nome Programa                         0
# Código Ação                           0
# Nome Ação                             0
# Código Plano Orçamentário             0
# Nome Plano Orçamentário               0
# Valor Empenhado                       0
# ...

# %% [markdown]
# Como podemos observar, existem um total de 0 - zero valores nulos, e em todas as colunas.

# %% [markdown]
# ## 5) Mostre os tipos das variáveis (se int, string, boolean, float...) e analise se alguma variável parece ter o tipo errado. Faça isso da maneira mais objetiva e otimizada possível.

# %%
df.dtypes
# Out:
# Código da Emenda                      object
# Ano da Emenda                          int64
# Tipo de Emenda                        object
# Código do Autor da Emenda             object
# Nome do Autor da Emenda               object
# Número da emenda                      object
# Localidade de aplicação do recurso    object
# Código Município IBGE                 object
# Município                             object
# Código UF IBGE                         int64
# UF                                    object
# Região                                object
# Código Função                         object
# Nome Função                           object
# Código Subfunção                      object
# Nome Subfunção                        object
# Código Programa                       object
# Nome Programa                         object
# Código Ação                           object
# Nome Ação                             object
# Código Plano Orçamentário             object
# ...

# %% [markdown]
# Se alguma coluna estiver com o tipo errado, escreva abaixo qual é e por que isso pode atrapalhar análises.
#
# **Dica:** Se alguma variável tiver no tipo o nome "object", isso se refere a texto.

# %% [markdown]
# Como podemos observar, temos algumas variáveis que estão com um tipo de variável incorreta da qual deveria estar. As colunas de valores financeiros estão com um tipo incorreto " int64 ou object ", quando deveriam ser "float64". Isso atrapalha porque impede cálculos precisos e análises estatísticas corretas, já que números tratados como texto não podem ser somados ou comparados

# %% [markdown]
# ## 6) Usando a coluna `Ano da Emenda` como base, descubra até que ano o dataset está atualizado (mostre as 8 primeiras linhas do df ordenado desc).

# %%
df.sort_values(by = "Ano da Emenda", ascending = False).head(8)
# Out:
#       Código da Emenda  Ano da Emenda  \
# 88564     202541820003           2025
# 88578     202544940001           2025
# 88595     202544840009           2025
# 88594     202544840008           2025
# 88577     202541820017           2025
# 88576     202541820016           2025
# 88575     202541820015           2025
# 88574     202541820014           2025
#
#                                           Tipo de Emenda  \
# 88564       Emenda Individual - Transferências Especiais
# 88578  Emenda Individual - Transferências com Finalid...
# 88595  Emenda Individual - Transferências com Finalid...
# 88594  Emenda Individual - Transferências com Finalid...
# 88577  Emenda Individual - Transferências com Finalid...
# 88576  Emenda Individual - Transferências com Finalid...
# 88575  Emenda Individual - Transferências com Finalid...
# 88574  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# ...

# %% [markdown]
# Explique: qual é o ano mais recente presente no dataset?

# %% [markdown]
# O ano mais recente como podemos observar no dataset é: 2025

# %% [markdown]
# ## 7) execute um  `describe()` e explique uma conclusão simples que você consegue tirar a partir das estatísticas (se algumas colunas deveriam aparecer no describe mas não aparecem, indique o motivo que você acredita que esteja causando esse problema).

# %%
df.describe()
# Out:
#        Ano da Emenda  Código UF IBGE
# count   88596.000000    8.859600e+04
# mean     2019.155109    2.943594e+06
# std         3.409323    1.264884e+06
# min      2014.000000   -1.400000e+01
# 25%      2016.000000    2.300000e+06
# 50%      2019.000000    3.100000e+06
# 75%      2022.000000    3.500000e+06
# max      2025.000000    5.300000e+06

# %% [markdown]
# Como podemos observar, a função "describe()" mostra qual o intervalo de anos e tamém sua destribuição, nisso consiguimos observar uma variabilidade de dados. E algumas colunas não aparecem pois está função só permite analisar colunas com dados numéricos, e não textuais.

# %% [markdown]
# ## 8) Mostre as últimas 5 linhas do dataset e escreva se a última linha parece completa (sem muitos nulos) ou não.

# %%
df.tail(5)
# Out:
#       Código da Emenda  Ano da Emenda  \
# 88591     202544840005           2025
# 88592     202544840006           2025
# 88593     202544840007           2025
# 88594     202544840008           2025
# 88595     202544840009           2025
#
#                                           Tipo de Emenda  \
# 88591       Emenda Individual - Transferências Especiais
# 88592  Emenda Individual - Transferências com Finalid...
# 88593  Emenda Individual - Transferências com Finalid...
# 88594  Emenda Individual - Transferências com Finalid...
# 88595  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 88591                      4484                   ZUCCO                5
# 88592                      4484                   ZUCCO                6
# 88593                      4484                   ZUCCO                7
# 88594                      4484                   ZUCCO                8
# ...

# %%
ultima_linha = df.tail(1)
print(ultima_linha.isnull().sum())
# Out:
# Código da Emenda                      0
# Ano da Emenda                         0
# Tipo de Emenda                        0
# Código do Autor da Emenda             0
# Nome do Autor da Emenda               0
# Número da emenda                      0
# Localidade de aplicação do recurso    0
# Código Município IBGE                 0
# Município                             0
# Código UF IBGE                        0
# UF                                    0
# Região                                0
# Código Função                         0
# Nome Função                           0
# Código Subfunção                      0
# Nome Subfunção                        0
# Código Programa                       0
# Nome Programa                         0
# Código Ação                           0
# Nome Ação                             0
# Código Plano Orçamentário             0
# Nome Plano Orçamentário               0
# Valor Empenhado                       0
# ...

# %% [markdown]
# Como podemos observar, a última linha não contém dados nulos, e a última linha está completa, ou seja, contém dados válidos em praticamente todas as colunas.

# %% [markdown]
# ## 9) existem valores duplicados no dataframe? Caso positivo, quantos?

# %%
duplicados = df.duplicated().sum()
print(f'O número de linhas duplicadas é: {duplicados}')
# Out:
# O número de linhas duplicadas é: 0

# %% [markdown]
# Como podemos observar através da função, não existem valores duplicados.
